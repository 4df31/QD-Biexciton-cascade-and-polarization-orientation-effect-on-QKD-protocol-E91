# %%
from os import cpu_count
from qiskit_aer import AerSimulator
from qiskit import*
from tqdm import tqdm
import numpy as np
from numpy import pi,sin,cos
from numpy.random import randint,choice
from qiskit.quantum_info import Statevector
from multiprocessing import Pool
from datetime import datetime
from sklearn.metrics import r2_score as r2
import pandas as pd

# %%
def parallel(vector:list,func):
    with Pool(int(cpu_count())) as p:
        return p.map(func,vector)

# %% [markdown]
# ## Quantum Circuits Functions

# %%
def circuit_singlet_creator(angle_between_analyzers:float):
    """
        ----------------------------------------------
        ----- REMEBER TO MODIFY THIS ALPHA VALUE -----
        ----------------------------------------------
    """
    global_shift = global_alpha # this angel will deppend on main loop
    #global_shift = 0*pi/4 # alpha angle between analizer 0 and 1 for alice, angle between x and analizer 0 for bob
    # ---------------------------------------
    q = QuantumCircuit(2,2)
    # Noise indroduction based on QST experiments on QD XX-X-0 cascade
    state = choice(a=[0,1,2,3,4],p=[0.9107,0.0030,0.0138,0.0278,0.0447]) # Chen's based probabilities (diff(ρ_PURE,ρ_QST))
    # Pt = 0.9107
    if state == 0:
        q.h(0); q.rz(relative_phase,0); q.cx(0,1) # singlet state with phase
    elif state == 1:
        q.barrier()#q.z(0);q.z(1) # |00>
    elif state == 2:
        q.x(1); # |01>
    elif state == 3:
        q.x(0) # |10>
    elif state == 4:
        q.x(1);q.x(1) # |11>
    # Basis selection
    
    basis_alice = choice([0,1,2]); basis_bob = choice([1,2,3])
    basis_list = {0:0,1:global_shift,2:(global_shift+angle_between_analyzers),3:3*pi/8}
    q.ry(basis_list[basis_alice],0); q.ry(basis_list[basis_bob],1)
    # Measure
    q.measure(0,0); q.measure(1,1)
    basis = str(basis_alice)+str(basis_bob)
    
    return q,basis

# %%
def circuit_list_vector_creator(n_states:int,angle_between_analyzers:float):
    circs_basis_vector = parallel([angle_between_analyzers for k in range(n_states)],circuit_singlet_creator)
    return circs_basis_vector

# %%
def exec(q:QuantumCircuit):
    simulator = AerSimulator()
    circ = transpile(q, simulator)
    result = simulator.run(circ,shots=1).result().get_counts()
    return list(dict(result).keys())[0]

# %% [markdown]
# ## Post Execution Functions

# %%
def info_selector(circs_basis_vector:list):
    N = len(circs_basis_vector)
    circuits = list()
    basis=list()
    for k in range(N):
        circuits.append(circs_basis_vector[k][0])
        basis.append(circs_basis_vector[k][1])
    return [circuits,basis]

def probability_computation(basis_vector:list,result_vector:list):
    N_same_basis = 0
    N_anticorrelation = 0
    N_states = len(basis_vector)
    for k in range(N_states):
        if basis_vector[k] == '11' or basis_vector[k] == '22':
            N_same_basis += 1
            if result_vector[k] == '00' or result_vector[k] == '11':
                N_anticorrelation += 1
            else:
                pass
        else:
            pass
    return N_anticorrelation/N_same_basis

# %% [markdown]
# ## Run Function

# %%
def local_run (n_states:int,angle_1_2:float):
    info = circuit_list_vector_creator(n_states=n_states,angle_between_analyzers=angle_1_2)
    circuit_list, basis_list = info_selector(info)
    del info
    result = parallel(vector=circuit_list,func=exec)
    result = [result[k]for k in range(len(result))]
    del circuit_list
    fidelity = probability_computation(basis_vector=basis_list,result_vector=result)    
    return fidelity

# %% [markdown]
# # Analytical Model

# %%
def analytical(theta:float,beta:float,alpha:float):
    return (\
        cos(alpha)**4 + sin(alpha)**4 +\
        2 * (sin(alpha)**2) * (cos(alpha)**2) * cos(theta) + \
        cos(alpha+beta)**4 + sin(alpha+beta)**4 + \
        2 * (sin(alpha+beta)**2) * (cos(alpha+beta)**2) * cos(theta)\
        )/2  

def model_noise(θ,β,α,Pt):
    # α/2 for the change between spin and polarization representation
    return analytical(θ,β,α/2)*Pt + ((1-Pt)/2.0)

# %%
def correlation_computing(n_execs:int,n_phase:int,experiment:np.ndarray):
    theta = np.linspace(0,2*pi,n_phase)
    beta = np.linspace(0,pi,n_execs)
    """
        ----------------------------------------------
        ----- REMEBER TO MODIFY THIS ALPHA VALUE -----
        ----------------------------------------------
    """
    alpha = global_alpha
    theoretical = np.array([[model_noise(θ=t,β=b,α=alpha,Pt=0.9107) for t in theta] for b in beta])
    return  r2(y_true=theoretical,y_pred=experiment)

# %%
def main(n_states:int,n_execs:int):
    fidelity = list()
    for k in range(n_execs):
        fidelity.append(local_run(n_states=n_states,angle_1_2=angle_between_analyzers[k]))
    return np.array(fidelity)
    
def save_info_to_csv(column:list,backend_name,time_str):
    path_name = f"./Fig_5/"
    file_name = f"{backend_name}_{time_str}.csv"
    string = ""
    for data in column:
        string += f"{data},"
    with open(path_name+file_name, "a") as file:
        file.write(string + "\n")
    return

# %%
import numpy as np
from datetime import datetime
# from tqdm import tqdm  # (Assuming this is imported above)
# from math import pi    # (Assuming this is imported above)

def run_mode():
    print("single point execution? Y/N")
    run_opt_bool = input().lower() # .lower() handles both 'y' and 'Y' automatically!
    
    if run_opt_bool == 'y':
        return True
    elif run_opt_bool == 'n':
        return False
    else:
        # FIX: Added return so it correctly passes the boolean up the chain
        return run_mode() 

single_point = run_mode()

# FIX: Declare your globals ONCE, at the top level of the logic block
global angle_between_analyzers
global relative_phase
global global_alpha

if single_point:
    states_list = [1000, 5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000]

    angle_between_analyzers = [pi/2]
    relative_phase = pi
    
    performance_parameter = np.zeros(len(states_list)) 
    time_now = datetime.now().strftime("%d_%m_%Y_%H_%M_%S")
    
    for k, states in enumerate(states_list):
        print(f"states = {states:8d}")
        out = main(n_states=states, n_execs=1)
        performance_parameter[k] = out[0]
        save_info_to_csv(column=out, backend_name=f"NOISY_single_point_AER_SIM", time_str=time_now)
else:
    # FIX: Uncommented states_list so the loop below actually has data to run on
    
    # states_list = [45000, 30000, 25000, 10000, 5000]  # run 1
    # states_list = [450, 300, 250, 100, 50]  # run 1
    # states_list = [40000, 35000, 20000, 15000, 1000]  # run 2
    states_list = [15000] # For plotting fig 5 of the manuscript
    r2_values = list()
    #alpha_values = np.array([k*pi/4.0 for k in range(6)],dtype=np.float64)
    alpha_values = np.array([pi/4],dtype=np.float64) # For plotting fig 5 of the manuscript

    for alpha in alpha_values:
        global_alpha = alpha
        print(f"alpha = {global_alpha/pi} *pi")
        for states in states_list:
            execs = int(1) # steps of angle β between coincident analyzers beta parameter between 0 and π
            n_phase = int(100) # steps of FSS parameter theta between 0 and 2 pi
        
            phase = np.linspace(0, 2*pi, n_phase) # θ_FSS
            #angle_between_analyzers = np.linspace(0, 2*pi, execs) # β
            angle_between_analyzers = np.array([pi/4],dtype=np.float64) # For plotting fig 5 of the manuscript
        
            time_now = datetime.now().strftime("%d_%m_%Y_%H_%M_%S")
            mesh = list()
            
            for rel_phase in tqdm(phase, desc="progress: "):
                
                relative_phase = rel_phase # phase between bell pair state
                #---------------------------------------------------
                out = main(n_states=states, n_execs=execs)
                mesh.append(out)
                save_info_to_csv(column=out, backend_name=f"alpha_{global_alpha/pi}pi_Pt_0.9107_20x20_mesh_{states:1.1E}_states_SIM", time_str=time_now)
                #---------------------------------------------------
                
            mesh = np.array(mesh, dtype=np.float64)
        
            r2_values.append(correlation_computing(n_execs=execs, n_phase=n_phase, experiment=mesh))
            
        r2_filename = f"Fig_5_R2_Pt_0.9107_{datetime.now().strftime('%d_%m_%Y_%H_%M_%S')}.csv"
        with open("./Fig_5/"+r2_filename, "w") as file:
            file.write("'n_states','r2'\n")
            for n, r in zip(states_list, r2_values):
                file.write(f"{n},{r}\n")
    """
    states_list = [1000, 5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000]
    n_phase = 30
    angle_between_analyzers = [pi/2]
    phase = np.linspace(0, 2*pi, n_phase)
    
    for k, states in enumerate(states_list):
        time_now = datetime.now().strftime("%d_%m_%Y_%H_%M_%S")
        print(f"states = {states:8d}")
        performance_parameter = list()
        for rel_phase in tqdm(phase, desc="progress: "):
            relative_phase = rel_phase
            out = main(n_states=states, n_execs=1)
            performance_parameter.append(out[0])
            save_info_to_csv(column=out, backend_name=f"NOISY_{states}_FSS_parametrized_AER_SIM", time_str=time_now)
    """
# Out:
# single point execution? Y/N
#  n
# alpha = 0.25 *pi
# progress:   0%|                                 | 0/100 [00:00<?, ?it/s]Process ForkPoolWorker-18:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-14:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_7142/1735412577.py", line 3, in exec
#     circ = transpile(q, simulator)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_7142/1735412577.py", line 3, in exec
#     circ = transpile(q, simulator)
#   File "/tmp/ipykernel_7142/1735412577.py", line 3, in exec
#     circ = transpile(q, simulator)
#   File "/tmp/ipykernel_7142/1735412577.py", line 3, in exec
#     circ = transpile(q, simulator)
#   File "/tmp/ipykernel_7142/1735412577.py", line 3, in exec
#     circ = transpile(q, simulator)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_7142/1735412577.py", line 3, in exec
#     circ = transpile(q, simulator)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/compiler/transpiler.py", line 269, in transpile
#     pm = generate_preset_pass_manager(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/compiler/transpiler.py", line 269, in transpile
#     pm = generate_preset_pass_manager(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/compiler/transpiler.py", line 269, in transpile
#     pm = generate_preset_pass_manager(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/compiler/transpiler.py", line 269, in transpile
#     pm = generate_preset_pass_manager(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/compiler/transpiler.py", line 269, in transpile
#     pm = generate_preset_pass_manager(
#   File "/tmp/ipykernel_7142/1735412577.py", line 3, in exec
#     circ = transpile(q, simulator)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 221, in generate_preset_pass_manager
#     basis_gates, name_mapping = _parse_basis_gates(basis_gates, backend)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 221, in generate_preset_pass_manager
#     basis_gates, name_mapping = _parse_basis_gates(basis_gates, backend)
#   File "/tmp/ipykernel_7142/1735412577.py", line 3, in exec
#     circ = transpile(q, simulator)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 221, in generate_preset_pass_manager
#     basis_gates, name_mapping = _parse_basis_gates(basis_gates, backend)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/compiler/transpiler.py", line 269, in transpile
#     pm = generate_preset_pass_manager(
#   File "/tmp/ipykernel_7142/1735412577.py", line 3, in exec
#     circ = transpile(q, simulator)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 221, in generate_preset_pass_manager
#     basis_gates, name_mapping = _parse_basis_gates(basis_gates, backend)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in _parse_basis_gates
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 360, in _parse_basis_gates
#     if inst not in backend.operation_names:
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in _parse_basis_gates
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 221, in generate_preset_pass_manager
#     basis_gates, name_mapping = _parse_basis_gates(basis_gates, backend)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/compiler/transpiler.py", line 269, in transpile
#     pm = generate_preset_pass_manager(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/compiler/transpiler.py", line 269, in transpile
#     pm = generate_preset_pass_manager(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 221, in generate_preset_pass_manager
#     basis_gates, name_mapping = _parse_basis_gates(basis_gates, backend)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 360, in _parse_basis_gates
#     if inst not in backend.operation_names:
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in <dictcomp>
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/providers/backend.py", line 146, in operation_names
#     return list(self.target.operation_names)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in <dictcomp>
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in _parse_basis_gates
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/compiler/transpiler.py", line 269, in transpile
#     pm = generate_preset_pass_manager(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 315, in generate_preset_pass_manager
#     pm = level_2_pass_manager(pm_config)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/providers/backend.py", line 146, in operation_names
#     return list(self.target.operation_names)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in <dictcomp>
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
# KeyboardInterrupt
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in _parse_basis_gates
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit_aer/backends/aerbackend.py", line 421, in target
#     target.add_instruction(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 221, in generate_preset_pass_manager
#     basis_gates, name_mapping = _parse_basis_gates(basis_gates, backend)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/level2.py", line 97, in level_2_pass_manager
#     init = plugin_manager.get_passmanager_stage(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit_aer/backends/aerbackend.py", line 421, in target
#     target.add_instruction(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 221, in generate_preset_pass_manager
#     basis_gates, name_mapping = _parse_basis_gates(basis_gates, backend)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit_aer/backends/aerbackend.py", line 421, in target
#     target.add_instruction(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in <dictcomp>
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
# KeyboardInterrupt
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/target.py", line 461, in add_instruction
#     super().add_instruction(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/plugin.py", line 235, in get_passmanager_stage
#     return self._build_pm(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in _parse_basis_gates
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in _parse_basis_gates
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
# KeyboardInterrupt
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in <dictcomp>
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/plugin.py", line 272, in _build_pm
#     return plugin_obj.obj.pass_manager(pm_config, optimization_level)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py", line 354, in <dictcomp>
#     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/builtin_plugins.py", line 171, in pass_manager
#     Split2QUnitaries(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit_aer/backends/aerbackend.py", line 256, in target
#     configuration = self.configuration()
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit_aer/backends/aerbackend.py", line 260, in target
#     qiskit_inst_mapping = get_standard_gate_name_mapping()
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py", line 49, in __call__
#     pass_instance = type.__call__(cls, *args, **kwargs)
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/passes/optimization/split_2q_unitaries.py", line 40, in __init__
#     super().__init__()
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit_aer/backends/aer_simulator.py", line 896, in configuration
#     method = getattr(self.options, "method", "automatic")
# KeyboardInterrupt
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit_aer/backends/aerbackend.py", line 260, in target
#     qiskit_inst_mapping = get_standard_gate_name_mapping()
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/transpiler/target.py", line 461, in add_instruction
#     super().add_instruction(
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/circuit/library/standard_gates/__init__.py", line 136, in get_standard_gate_name_mapping
#     Delay(time),
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit_aer/backends/aerbackend.py", line 260, in target
#     qiskit_inst_mapping = get_standard_gate_name_mapping()
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/circuit/library/standard_gates/__init__.py", line 140, in get_standard_gate_name_mapping
#     name_mapping = {gate.name: gate for gate in gates}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/circuit/library/standard_gates/__init__.py", line 140, in get_standard_gate_name_mapping
#     name_mapping = {gate.name: gate for gate in gates}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/circuit/library/standard_gates/__init__.py", line 140, in <dictcomp>
#     name_mapping = {gate.name: gate for gate in gates}
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/circuit/controlledgate.py", line 143, in name
#     @property
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/circuit/delay.py", line 47, in __init__
#     duration, self._unit = self._validate_arguments(duration, unit)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/qadrian/APPS/miniconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/circuit/library/standard_gates/__init__.py", line 140, in <dictcomp>
#     name_mapping = {gate.name: gate for gate in gates}
# KeyboardInterrupt
# KeyboardInterrupt
# progress:   0%|                                 | 0/100 [02:46<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 68
#      66 relative_phase = rel_phase # phase between bell pair state
#      67 #---------------------------------------------------
# ---> 68 out = main(n_states=states, n_execs=execs)
#      69 mesh.append(out)
#      70 save_info_to_csv(column=out, backend_name=f"alpha_{global_alpha/pi}pi_Pt_0.9107_20x20_mesh_{states:1.1E}_states_SIM", time_str=time_now)
#
# Cell In[10], line 4, in main(n_states, n_execs)
#       2 fidelity = list()
#       3 for k in range(n_execs):
# ----> 4     fidelity.append(local_run(n_states=n_states,angle_1_2=angle_between_analyzers[k]))
#       5 return np.array(fidelity)
#
# Cell In[7], line 5, in local_run(n_states, angle_1_2)
#       3 circuit_list, basis_list = info_selector(info)
#       4 del info
# ----> 5 result = parallel(vector=circuit_list,func=exec)
#       6 result = [result[k]for k in range(len(result))]
#       7 del circuit_list
#
# Cell In[2], line 3, in parallel(vector, func)
#       1 def parallel(vector:list,func):
#       2     with Pool(int(cpu_count())) as p:
# ----> 3         return p.map(func,vector)
#
# File ~/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/APPS/miniconda3/envs/qiskit/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/APPS/miniconda3/envs/qiskit/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/APPS/miniconda3/envs/qiskit/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
